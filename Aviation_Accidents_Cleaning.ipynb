# %% [markdown]
# # Aviation Accidents Analysis
#
# You are part of a consulting firm that is tasked to do an analysis of commercial and passenger jet airline safety. The client (an airline/airplane insurer) is interested in knowing what types of aircraft (makes/models) exhibit low rates of total destruction and low likelihood of fatal or serious passenger injuries in the event of an accident. They are also interested in any general variables/conditions that might be at play. Your analysis will be based off of aviation accident data accumulated from the years 1948-2023.
#
# Our client is only interested in airplane makes/models that are professional builds and could potentially still be active. Assume a max lifetime of 40 years for a make/model retirement and make sure to filter your data accordingly (i.e. from 1983 onwards). They would also like separate recommendations for small aircraft vs. larger passenger models. **In addition, make sure that claims that you make are statistically robust and that you have enough samples when making comparisons between groups.**
#
#
# In this summative assessment you will demonstrate your ability to:
# - **Use Pandas to load, inspect, and clean the dataset appropriately.**
# - **Transform relevant columns to create measures that address the problem at hand.**
# - conduct EDA: visualization and statistical measures to systematically understand the structure of the data
# - recommend a set of airplanes and makes conforming to the client's request and identify at least *two* factors contributing to airplane safety. You must provide supporting evidence (visuals, summary statistics, tables) for each claim you make.

# %% [markdown]
# ### Make relevant library imports

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Data Loading and Inspection

# %% [markdown]
# ### Load in data from the relevant directory and inspect the dataframe.
# - inspect NaNs, datatypes, and summary statistics

# %%
df = pd.read_csv('C:/Users/user/Aviation_Assessment/Summative_Assessment_Lab/data/AviationData.csv', encoding='latin1')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[356], line 1
# ----> 1 df = pd.read_csv('C:/Users/user/Aviation_Assessment/Summative_Assessment_Lab/data/AviationData.csv', encoding='latin1')
#       2 df.head()
#
# File c:\Users\user\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\user\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\user\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\user\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\user\anaconda3\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/user/Aviation_Assessment/Summative_Assessment_Lab/data/AviationData.csv'

# %%
df.columns
# Out:
# Index(['Event.Id', 'Investigation.Type', 'Accident.Number', 'Event.Date',
#        'Location', 'Country', 'Latitude', 'Longitude', 'Airport.Code',
#        'Airport.Name', 'Injury.Severity', 'Aircraft.damage',
#        'Aircraft.Category', 'Registration.Number', 'Make', 'Model',
#        'Amateur.Built', 'Number.of.Engines', 'Engine.Type', 'FAR.Description',
#        'Schedule', 'Purpose.of.flight', 'Air.carrier', 'Total.Fatal.Injuries',
#        'Total.Serious.Injuries', 'Total.Minor.Injuries', 'Total.Uninjured',
#        'Weather.Condition', 'Broad.phase.of.flight', 'Report.Status',
#        'Publication.Date'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0      20001218X45444           Accident      SEA87LA080  1948-10-24
# 1      20001218X45447           Accident      LAX94LA336  1962-07-19
# 2      20061025X01555           Accident      NYC07LA005  1974-08-30
# 3      20001218X45448           Accident      LAX96LA321  1977-06-19
# 4      20041105X01764           Accident      CHI79FA064  1979-08-02
# ...               ...                ...             ...         ...
# 88884  20221227106491           Accident      ERA23LA093  2022-12-26
# 88885  20221227106494           Accident      ERA23LA095  2022-12-26
# 88886  20221227106497           Accident      WPR23LA075  2022-12-26
# 88887  20221227106498           Accident      WPR23LA076  2022-12-26
# 88888  20221230106513           Accident      ERA23LA097  2022-12-29
#
#               Location        Country   Latitude  Longitude Airport.Code  \
# 0      MOOSE CREEK, ID  United States        NaN        NaN          NaN
# 1       BRIDGEPORT, CA  United States        NaN        NaN          NaN
# 2        Saltville, VA  United States  36.922223 -81.878056          NaN
# 3           EUREKA, CA  United States        NaN        NaN          NaN
# 4           Canton, OH  United States        NaN        NaN          NaN
# ...                ...            ...        ...        ...          ...
# 88884    Annapolis, MD  United States        NaN        NaN          NaN
# 88885      Hampton, NH  United States        NaN        NaN          NaN
# 88886       Payson, AZ  United States    341525N   1112021W          PAN
# 88887       Morgan, UT  United States        NaN        NaN          NaN
# 88888       Athens, GA  United States        NaN        NaN          NaN
#
#       Airport.Name  ... Purpose.of.flight         Air.carrier  \
# 0              NaN  ...          Personal                 NaN
# 1              NaN  ...          Personal                 NaN
# 2              NaN  ...          Personal                 NaN
# 3              NaN  ...          Personal                 NaN
# 4              NaN  ...          Personal                 NaN
# ...            ...  ...               ...                 ...
# 88884          NaN  ...          Personal                 NaN
# 88885          NaN  ...               NaN                 NaN
# 88886       PAYSON  ...          Personal                 NaN
# 88887          NaN  ...          Personal  MC CESSNA 210N LLC
# 88888          NaN  ...          Personal                 NaN
#
#       Total.Fatal.Injuries Total.Serious.Injuries Total.Minor.Injuries  \
# 0                      2.0                    0.0                  0.0
# 1                      4.0                    0.0                  0.0
# 2                      3.0                    NaN                  NaN
# 3                      2.0                    0.0                  0.0
# 4                      1.0                    2.0                  NaN
# ...                    ...                    ...                  ...
# 88884                  0.0                    1.0                  0.0
# 88885                  0.0                    0.0                  0.0
# 88886                  0.0                    0.0                  0.0
# 88887                  0.0                    0.0                  0.0
# 88888                  0.0                    1.0                  0.0
#
#       Total.Uninjured Weather.Condition  Broad.phase.of.flight  \
# 0                 0.0               UNK                 Cruise
# 1                 0.0               UNK                Unknown
# 2                 NaN               IMC                 Cruise
# 3                 0.0               IMC                 Cruise
# 4                 0.0               VMC               Approach
# ...               ...               ...                    ...
# 88884             0.0               NaN                    NaN
# 88885             0.0               NaN                    NaN
# 88886             1.0               VMC                    NaN
# 88887             0.0               NaN                    NaN
# 88888             1.0               NaN                    NaN
#
#         Report.Status Publication.Date
# 0      Probable Cause              NaN
# 1      Probable Cause       19-09-1996
# 2      Probable Cause       26-02-2007
# 3      Probable Cause       12-09-2000
# 4      Probable Cause       16-04-1980
# ...               ...              ...
# 88884             NaN       29-12-2022
# 88885             NaN              NaN
# 88886             NaN       27-12-2022
# 88887             NaN              NaN
# 88888             NaN       30-12-2022
#
# [88889 rows x 31 columns]>

# %% [markdown]
# The dataset has 88,889 rows and 31 columns.

# %%
df.dtypes
# Out:
# Event.Id                   object
# Investigation.Type         object
# Accident.Number            object
# Event.Date                 object
# Location                   object
# Country                    object
# Latitude                   object
# Longitude                  object
# Airport.Code               object
# Airport.Name               object
# Injury.Severity            object
# Aircraft.damage            object
# Aircraft.Category          object
# Registration.Number        object
# Make                       object
# Model                      object
# Amateur.Built              object
# Number.of.Engines         float64
# Engine.Type                object
# FAR.Description            object
# Schedule                   object
# Purpose.of.flight          object
# Air.carrier                object
# Total.Fatal.Injuries      float64
# Total.Serious.Injuries    float64
# Total.Minor.Injuries      float64
# Total.Uninjured           float64
# Weather.Condition          object
# Broad.phase.of.flight      object
# Report.Status              object
# Publication.Date           object
# dtype: object

# %% [markdown]
# Most of the data here are strings. Some of them will be changed to the correct data type.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# There were no duplicates in the dataset

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Schedule                  76307
# Air.carrier               72241
# FAR.Description           56866
# Aircraft.Category         56602
# Longitude                 54516
# Latitude                  54507
# Airport.Code              38757
# Airport.Name              36185
# Broad.phase.of.flight     27165
# Publication.Date          13771
# Total.Serious.Injuries    12510
# Total.Minor.Injuries      11933
# Total.Fatal.Injuries      11401
# Engine.Type                7096
# Report.Status              6384
# Purpose.of.flight          6192
# Number.of.Engines          6084
# Total.Uninjured            5912
# Weather.Condition          4492
# Aircraft.damage            3194
# Registration.Number        1382
# Injury.Severity            1000
# Country                     226
# Amateur.Built               102
# Model                        92
# Make                         63
# Location                     52
# Investigation.Type            0
# Event.Date                    0
# Accident.Number               0
# Event.Id                      0
# dtype: int64

# %% [markdown]
# There were quite a large number of missing values in some of the columns in the dataset. Handling of the missing values will mainly be focused on the columns that satisfy the client's needs from the analysis.

# %% [markdown]
# I decided to drop the rows with the missing values in Make, Model and Amateur bulit columns because they make up less than 1% of the dataset and also, without values in those columns, those rows are not valuable anymore.

# %%
df = df.dropna(subset=['Make', 'Model', 'Amateur.Built'])

# %%
df.columns
# Out:
# Index(['Event.Id', 'Investigation.Type', 'Accident.Number', 'Event.Date',
#        'Location', 'Country', 'Latitude', 'Longitude', 'Airport.Code',
#        'Airport.Name', 'Injury.Severity', 'Aircraft.damage',
#        'Aircraft.Category', 'Registration.Number', 'Make', 'Model',
#        'Amateur.Built', 'Number.of.Engines', 'Engine.Type', 'FAR.Description',
#        'Schedule', 'Purpose.of.flight', 'Air.carrier', 'Total.Fatal.Injuries',
#        'Total.Serious.Injuries', 'Total.Minor.Injuries', 'Total.Uninjured',
#        'Weather.Condition', 'Broad.phase.of.flight', 'Report.Status',
#        'Publication.Date'],
#       dtype='object')

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Filtering aircrafts and events

# %% [markdown]
# We want to filter the dataset to include aircraft that the client is interested in an analysis of:
# - inspect relevant columns
# - figure out any reasonable imputations
# - filter the dataset

# %% [markdown]
# The code below changes the Event date data type to date.

# %%
df['Event.Date'] = pd.to_datetime(df['Event.Date'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_5276\1540095821.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Event.Date'] = pd.to_datetime(df['Event.Date'])

# %% [markdown]
# The code below filters the data by the event date specified by the client, that is from 1983 to 2023.

# %%
df = df[df['Event.Date'] >= '1983-01-01']

# %% [markdown]
# The code below filters the dataset by airplanes since the client is only interested in airplanes.

# %%
df = df[df['Aircraft.Category'] == 'Airplane']

# %% [markdown]
# The code below filters the data by the Amateur Built, since the client wants airplanes that were proffesionally built only.

# %%
df = df[df['Amateur.Built'] == 'No']

# %% [markdown]
# The code below filters the data by the investigation type, since the client is already interested in accidents and not incidents.

# %%
df = df[df['Investigation.Type'] == 'Accident']

# %% [markdown]
# ### Cleaning and constructing Key Measurables
#
# Injuries and robustness to destruction are a key interest point for the client. Clean and impute relevant columns and then create derived fields that best quantifies what the client wishes to track. **Use commenting or markdown to explain any cleaning assumptions as well as any derived columns you create.**

# %% [markdown]
# **Construct metric for fatal/serious injuries**
#
# *Hint:* Estimate the total number of passengers on each flight. The likelihood of serious / fatal injury can be estimated as a fraction from this.

# %% [markdown]
# This is the total number of passengers on each flight

# %% [markdown]
# I chose to assume that if no injuries were recorded, then it means there were no injuries. So i filled all the missing values with 0.

# %%
injury_cols = ['Total.Fatal.Injuries', 'Total.Serious.Injuries', 
               'Total.Minor.Injuries', 'Total.Uninjured']
df[injury_cols] = df[injury_cols].fillna(0)

# %% [markdown]
# The code below gives the total number of passengers per flight.

# %%
df['Total.Passengers'] = df[injury_cols].sum(axis=1)

# %% [markdown]
# Below is the code to check the rate of Fatal/Seroius injuries.

# %%
df['Fatal.Serious.Rate'] = (df['Total.Fatal.Injuries'] + df['Total.Serious.Injuries']) / df['Total.Passengers']

# %% [markdown]
# **Aircraft.Damage**
# - identify and execute any cleaning tasks
# - construct a derived column tracking whether an aircraft was destroyed or not.

# %% [markdown]
# The code below fills in all missing values in the aircraft damage column with unknown. This assumes that if the type of damage was not recorded, then it was unknown.

# %%
df['Aircraft.damage'].fillna('Unknown')
# Out:
# 4171       Destroyed
# 4285         Unknown
# 5960       Destroyed
# 6669         Unknown
# 6806     Substantial
#             ...
# 88869    Substantial
# 88873    Substantial
# 88876    Substantial
# 88877    Substantial
# 88886    Substantial
# Name: Aircraft.damage, Length: 19923, dtype: object

# %% [markdown]
# The code creates a column called Destroyed.Aircrafts, which with 1, it means that aircraft damage was totally Destroyed, which is what the clients wants to know. If it shows 0, it means for those aircrafts the damage was either Unknown, Subsatantial or Minor.

# %%
df['Destroyed.Aircrafts'] = (df['Aircraft.damage'] == 'Destroyed').astype(int)

# %% [markdown]
# ### Investigate the *Make* column
# - Identify cleaning tasks here
# - List cleaning tasks clearly in markdown
# - Execute the cleaning tasks
# - For your analysis, keep Makes with a reasonable number (you can put the threshold at 50 though lower could work as well)

# %% [markdown]
# The code below makes the necessary replacements in the file.

# %%
make_replacements = {
    'Dehavilland': 'De Havilland',
    'Air Tractor Inc': 'Air Tractor',
    'Aviat Aircraft Inc': 'Aviat',
    'Ayres Corporation': 'Ayres',
    'Cirrus Design Corp': 'Cirrus',
    'Diamond Aircraft Ind Inc': 'Diamond',
    'Mooney Aircraft Corp.': 'Mooney',
}
df['Make'] = df['Make'].replace(make_replacements)

# %%
df['Make'] = df['Make'].str.title().str.strip()

# %% [markdown]
# The code above ensures there are no unwanted whitespaces and the casings are the same.

# %%
make_counts = df['Make'].value_counts()
valid_makes = make_counts[make_counts >= 30].index
df = df[df['Make'].isin(valid_makes)]

# %% [markdown]
# I have chosen 30 as the threshold as 30.

# %% [markdown]
# ### Inspect Model column
# - Get rid of any NaNs.
# - Inspect the column and counts for each model/make. Are model labels unique to each make?
# - If not, create a derived column that is a unique identifier for a given plane type.

# %%
df['Model'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Model'] = df['Model'].str.upper().str.strip()

# %% [markdown]
# The code below confirms that not every model label is unique to the make.

# %%
df.groupby('Model')['Make'].nunique().sort_values(ascending=False)
# Out:
# Model
# S2R                 5
# S 2R                4
# S-2R                4
# 112                 3
# 8KCAB               3
#                    ..
# A380                1
# A36TC               1
# A36 - UNDESIGNAT    1
# A36 - TC            1
# YPF-7               1
# Name: Make, Length: 1959, dtype: int64

# %% [markdown]
# The above code creates a new column 'Make_Model' which becomes the unique identifier for a given plane type. It combines the Make and Model into one name.

# %%
df['Make_Model'] = df['Make'] + ' ' + df['Model']

# %% [markdown]
# ### Cleaning other columns
# - there are other columns containing data that might be related to the outcome of an accident. We list a few here:
# - Engine.Type
# - Weather.Condition
# - Number.of.Engines
# - Purpose.of.flight
# - Broad.phase.of.flight
#
# Inspect and identify potential cleaning tasks in each of the above columns. Execute those cleaning tasks.
#
# **Note**: You do not necessarily need to impute or drop NaNs here.

# %%
df['Engine.Type'].value_counts(dropna=False)
# Out:
# Engine.Type
# Reciprocating    13013
# NaN               2520
# Turbo Prop         933
# Turbo Fan          402
# Unknown             71
# Turbo Jet           57
# Turbo Shaft          9
# UNK                  1
# Name: count, dtype: int64

# %%
df['Engine.Type'] = df['Engine.Type'].replace({'UNK': 'Unknown'})

# %% [markdown]
# Th unknown values in the engine type column have been standardized.

# %%
df['Weather.Condition'].value_counts(dropna=False)
# Out:
# Weather.Condition
# VMC    14369
# NaN     1549
# IMC      892
# Unk      150
# UNK       46
# Name: count, dtype: int64

# %%
df['Weather.Condition'] = df['Weather.Condition'].replace({'Unk': 'Unknown', 'UNK': 'Unknown'})

# %% [markdown]
# The unknown values in the weather condition column have been standardized.

# %%
df['Number.of.Engines'].value_counts(dropna=False)
# Out:
# Number.of.Engines
# 1.0    13455
# 2.0     2026
# NaN     1470
# 4.0       35
# 3.0       16
# 0.0        4
# Name: count, dtype: int64

# %%
df = df[df['Number.of.Engines'] != 0]

# %% [markdown]
# Records with 0 number of engines have been dropped, since they are not physically logical and they hold a small percentage of the data and dropping them does npt affect the analysis greatly.

# %%
df['Purpose.of.flight'].value_counts(dropna=False)
# Out:
# Purpose.of.flight
# Personal                     9982
# Instructional                2457
# NaN                          1986
# Aerial Application            771
# Business                      401
# Positioning                   264
# Unknown                       262
# Skydiving                     156
# Aerial Observation            149
# Other Work Use                126
# Banner Tow                     86
# Flight Test                    74
# Ferry                          74
# Executive/corporate            61
# Public Aircraft - Federal      30
# Glider Tow                     29
# Public Aircraft                25
# Public Aircraft - State        21
# Air Race show                  15
# Firefighting                   13
# Public Aircraft - Local        11
# PUBS                            3
# Air Race/show                   2
# Air Drop                        2
# ASHO                            2
# Name: count, dtype: int64

# %%
df['Purpose.of.flight'] = df['Purpose.of.flight'].replace({'Air Race/show': 'Air Race show', 'Public Aircraft - Federal': 'Public Aircraft',
    'Public Aircraft - State': 'Public Aircraft',
    'Public Aircraft - Local': 'Public Aircraft'})

# %% [markdown]
# In the purpose of flight column, the subcategories of Public aircraft have been merged into one, since the distinctions do not matter to the analysis.

# %%
df['Broad.phase.of.flight'].value_counts(dropna=False)
# Out:
# Broad.phase.of.flight
# NaN            14551
# Landing         1119
# Takeoff          425
# Cruise           237
# Approach         212
# Maneuvering      130
# Taxi              92
# Go-around         82
# Descent           59
# Climb             48
# Standing          35
# Unknown           10
# Other              2
# Name: count, dtype: int64

# %% [markdown]
# The Broad phase of flight column does not need any cleaning.

# %% [markdown]
# ### Column Removal
# - inspect the dataframe and drop any columns that have too many NaNs

# %% [markdown]
# The columns below have been dropped because they contain a large number of missing values.

# %%
df.drop(columns=[
    'Schedule',            
    'Air.carrier',         
    'FAR.Description',     
    'Longitude',           
    'Latitude',            
    'Airport.Code',        
    'Airport.Name',        
    'Publication.Date',    
], inplace=True)

# %%
df.shape
# Out:
# (17002, 27)

# %% [markdown]
# After several cleaning steps the dataset has 17,002 rows and 27 columns, compared to 88,889 rows and 31 columns of the raw data.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17002 entries, 4171 to 88886
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                17002 non-null  object
#  1   Investigation.Type      17002 non-null  object
#  2   Accident.Number         17002 non-null  object
#  3   Event.Date              17002 non-null  datetime64[ns]
#  4   Location                16999 non-null  object
#  5   Country                 17001 non-null  object
#  6   Injury.Severity         16816 non-null  object
#  7   Aircraft.damage         16624 non-null  object
#  8   Aircraft.Category       17002 non-null  object
#  9   Registration.Number     16876 non-null  object
#  10  Make                    17002 non-null  object
#  11  Model                   17002 non-null  object
#  12  Amateur.Built           17002 non-null  object
#  13  Number.of.Engines       15532 non-null  float64
#  14  Engine.Type             14482 non-null  object
#  15  Purpose.of.flight       15016 non-null  object
#  16  Total.Fatal.Injuries    17002 non-null  float64
#  17  Total.Serious.Injuries  17002 non-null  float64
#  18  Total.Minor.Injuries    17002 non-null  float64
#  19  Total.Uninjured         17002 non-null  float64
#  20  Weather.Condition       15453 non-null  object
#  21  Broad.phase.of.flight   2451 non-null   object
#  22  Report.Status           13987 non-null  object
#  23  Total.Passengers        17002 non-null  float64
#  24  Fatal.Serious.Rate      16797 non-null  float64
#  25  Destroyed.Aircrafts     17002 non-null  int64
#  26  Make_Model              17002 non-null  object
# dtypes: datetime64[ns](1), float64(7), int64(1), object(18)
# memory usage: 3.6+ MB

# %%
df.isna().sum()
# Out:
# Event.Id                      0
# Investigation.Type            0
# Accident.Number               0
# Event.Date                    0
# Location                      3
# Country                       1
# Injury.Severity             186
# Aircraft.damage             378
# Aircraft.Category             0
# Registration.Number         126
# Make                          0
# Model                         0
# Amateur.Built                 0
# Number.of.Engines          1470
# Engine.Type                2520
# Purpose.of.flight          1986
# Total.Fatal.Injuries          0
# Total.Serious.Injuries        0
# Total.Minor.Injuries          0
# Total.Uninjured               0
# Weather.Condition          1549
# Broad.phase.of.flight     14551
# Report.Status              3015
# Total.Passengers              0
# Fatal.Serious.Rate          205
# Destroyed.Aircrafts           0
# Make_Model                    0
# dtype: int64

# %% [markdown]
# ### Save DataFrame to csv
# - its generally useful to save data to file/server after its in a sufficiently cleaned or intermediate state
# - the data can then be loaded directly in another notebook for further analysis
# - this helps keep your notebooks and workflow readable, clean and modularized

# %%
df.to_csv('AviationData.csv', index=False)

# %%
check = pd.read_csv('AviationData.csv')
check.shape
# Out:
# (17002, 27)

# %%
check.head
# Out:
# <bound method NDFrame.head of              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0      20001214X42331           Accident      ATL83FA140  1983-03-20
# 1      20001214X42672           Accident      FTW83LA177  1983-04-02
# 2      20001214X45188           Accident      NYC84LA028  1983-11-13
# 3      20001214X45339           Accident      LAX84LA110  1983-12-22
# 4      20001214X38957           Accident      ATL84LA120  1984-03-14
# ...               ...                ...             ...         ...
# 16997  20221212106444           Accident      ERA23LA085  2022-12-12
# 16998  20221213106455           Accident      WPR23LA065  2022-12-13
# 16999  20221215106463           Accident      ERA23LA090  2022-12-14
# 17000  20221219106470           Accident      ERA23LA091  2022-12-16
# 17001  20221227106497           Accident      WPR23LA075  2022-12-26
#
#                     Location        Country Injury.Severity Aircraft.damage  \
# 0             CROSSVILLE, TN  United States        Fatal(1)       Destroyed
# 1               MCKINNEY, TX  United States        Fatal(1)             NaN
# 2      MARTHA'S VINEYARD, MA  United States       Non-Fatal     Substantial
# 3      SANTA ROSA ISLAND, CA  United States       Non-Fatal     Substantial
# 4           MYRTLE BEACH, SC  United States       Non-Fatal     Substantial
# ...                      ...            ...             ...             ...
# 16997          Knoxville, TN  United States       Non-Fatal     Substantial
# 16998          Lewistown, MT  United States       Non-Fatal     Substantial
# 16999           San Juan, PR  United States       Non-Fatal     Substantial
# 17000        Brooksville, FL  United States           Minor     Substantial
# 17001             Payson, AZ  United States       Non-Fatal     Substantial
#
#       Aircraft.Category Registration.Number  ... Total.Serious.Injuries  \
# 0              Airplane              N9600W  ...                    1.0
# 1              Airplane              N927BA  ...                    0.0
# 2              Airplane              N1882D  ...                    0.0
# 3              Airplane              N2697K  ...                    0.0
# 4              Airplane              N7994R  ...                    0.0
# ...                 ...                 ...  ...                    ...
# 16997          Airplane              N783SF  ...                    0.0
# 16998          Airplane              C-GZPU  ...                    0.0
# 16999          Airplane              N416PC  ...                    0.0
# 17000          Airplane              N5405V  ...                    1.0
# 17001          Airplane              N749PJ  ...                    0.0
#
#       Total.Minor.Injuries Total.Uninjured  Weather.Condition  \
# 0                      0.0             0.0                IMC
# 1                      0.0             4.0                VMC
# 2                      0.0             1.0                VMC
# 3                      0.0             1.0                VMC
# 4                      0.0             1.0                VMC
# ...                    ...             ...                ...
# 16997                  0.0             1.0                VMC
# 16998                  0.0             1.0                NaN
# 16999                  0.0             1.0                VMC
# 17000                  0.0             0.0                VMC
# 17001                  0.0             1.0                VMC
#
#       Broad.phase.of.flight   Report.Status  Total.Passengers  \
# 0                    Cruise  Probable Cause               2.0
# 1                  Standing  Probable Cause               5.0
# 2                     Climb  Probable Cause               1.0
# 3                   Takeoff  Probable Cause               1.0
# 4                   Landing  Probable Cause               1.0
# ...                     ...             ...               ...
# 16997                   NaN             NaN               1.0
# 16998                   NaN             NaN               1.0
# 16999                   NaN             NaN               1.0
# 17000                   NaN             NaN               1.0
# 17001                   NaN             NaN               1.0
#
#        Fatal.Serious.Rate  Destroyed.Aircrafts  \
# 0                     1.0                    1
# 1                     0.2                    0
# 2                     0.0                    0
# 3                     0.0                    0
# 4                     0.0                    0
# ...                   ...                  ...
# 16997                 0.0                    0
# 16998                 0.0                    0
# 16999                 0.0                    0
# 17000                 1.0                    0
# 17001                 0.0                    0
#
#                              Make_Model
# 0                       Piper PA-28-140
# 1                    De Havilland DHC-6
# 2                             Beech C35
# 3                           Cessna 180K
# 4                              Beech 99
# ...                                 ...
# 16997                        Cessna 172
# 16998                        Piper PA42
# 16999           Cirrus Design Corp SR22
# 17000                      Cessna R172K
# 17001  American Champion Aircraft 8GCBC
#
# [17002 rows x 27 columns]>

# %% [markdown]
# The code above confirms if the saving worked.
